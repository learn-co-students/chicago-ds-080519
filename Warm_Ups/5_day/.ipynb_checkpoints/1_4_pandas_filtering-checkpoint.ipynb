# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
# we just use the one in our folder for readability purposes.
euro12 = pd.read_csv('Euro_2012_stats_TEAM.csv')
euro12.head(10)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12_goals = euro12.Goals

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
euro12.Team.describe()
# Out:
# count          16
# unique         16
# top       Denmark
# freq            1
# Name: Team, dtype: object

# %% [markdown]
# Hence, we see that there are in fact 16 teams that participated in this tournament.

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
euro12.columns.size
# Out:
# 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12.loc[:,['Team', 'Yellow Cards', 'Red Cards']]
discipline.head(10)
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0
# 5         Germany             4          0
# 6          Greece             9          1
# 7           Italy            16          0
# 8     Netherlands             5          0
# 9          Poland             7          1

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline_sorted = discipline.sort_values(['Red Cards', 'Yellow Cards'], axis=0, ascending=False)
discipline_sorted.head(10)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
discipline_sorted['Yellow Cards'].describe()['mean']
# Out:
# 7.4375

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
high_scoring_teams = euro12.loc[euro12['Goals'] >= 6]
high_scoring_teams.head(10)
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# ...

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
# Out:
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `item` has been deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-a6642bdc528e> in <module>()
# ----> 1 g_teams = euro12.loc[euro12['Team'].item().startswith('G')]
#       2 g_teams.head(10)
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/base.py in item(self)
#     738             stacklevel=2,
#     739         )
# --> 740         return self.values.item()
#     741
#     742     @property
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
euro12_f7 = euro12.iloc[:, :7]
euro12_f7
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
euro12_l3 = euro12.iloc[:,:-3]
euro12_l3.head(10)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12['Team'].isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
