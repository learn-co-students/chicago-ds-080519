# %% [markdown]
# <h1 style='text-align:center'> Module 1 Assessment</h1>

# %% [markdown]
# This assessment is designed to test your understanding of the Mod 1 material. It covers:
#
# * Python Fundamentals
# * Pandas and Numpy
# * Data Visualization
# * Exploring Statistical Data
#
#
#
# Read the instructions carefully. You will be asked both to write code and respond to a few short answer questions.
#
# #### Note on the short answer questions
# For the short answer questions _please use your own words_. The expectation is that you have **not** copied and pasted from an external source, even if you consult another source to help craft your response. While the short answer questions are not necessarily being assessed on grammatical correctness or sentence structure, do your best to communicate yourself clearly.

# %% [markdown]
# ## Python Fundamentals

# %% [markdown]
# In the first section, we will work with various Python data types and try to accomplish certain tasks using some Python fundamentals. Below, we've defined a dictionary with soccer player names as keys for nested dictionaries containing information about each players age, nationality, and a list of teams they have played for.

# %%
players = {
	'L. Messi': {
		'age': 31,
		'nationality': 'Argentina',
		'teams': ['Barcelona']
	},
	'Cristiano Ronaldo': {
		'age': 33,
		'nationality': 'Portugal',
		'teams': ['Juventus', 'Real Madrid', 'Manchester United']
	},
	'Neymar Jr': {
		'age': 26,
		'nationality': 'Brazil',
		'teams': ['Santos', 'Barcelona', 'Paris Saint-German']
	},
	'De Gea': {
		'age': 27,
		'nationality': 'Spain',
		'teams': ['Atletico Madrid', 'Manchester United']
	},
	'K. De Bruyne': {
		'age': 27,
		'nationality': 'Belgium',
		'teams': ['Chelsea', 'Manchester City']
	}
}

# %% [markdown]
# **1) Create a `list` of all the keys in the `players` dictionary. Use python's documentation on dictionaries for help if needed. Store the list of player names in a variable called `player_names` to use in the next question.**

# %%
# Get the list of all player names from the dictionary
player_names = list(players.keys())
player_names
# Out:
# ['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', 'De Gea', 'K. De Bruyne']

# %% [markdown]
# **2) Great! Now that we have each players name, let's use that information to create a `list` of `tuples` containing each player's name along with their nationality. Store the list in a variable called `player_nationalities`**

# %%
# Generate list of tuples such that the first element in the tuple is 
# a players name and the second is their nationality 
# Ex: [('L. Messi', 'Argentina'), ('Christiano Ronaldo', 'Portugal'), ...]
player_nationalities = [(p, players[p]['nationality']) for p in player_names]
player_nationalities
# Out:
# [('L. Messi', 'Argentina'),
#  ('Cristiano Ronaldo', 'Portugal'),
#  ('Neymar Jr', 'Brazil'),
#  ('De Gea', 'Spain'),
#  ('K. De Bruyne', 'Belgium')]

# %% [markdown]
# **3) Now, define a function called `get_players_on_team` that returns a `list` of the names of all the players who have played on a given team.**
#
# Your function should take two arguments:
# * a dictionary of player information
# * a `string` of the team you are trying to find the players for
#
# **Be sure that your function has a `return` statement.**

# %%
# Define your get_players_on_team function here.
def get_players_on_team(dictionary, team_name):
    team_players = []
    for player in dictionary:
        info = dictionary[player]
        if team_name in info['teams']:
            team_players.append(player)
    return team_players

# %%
players_on_manchester_united = get_players_on_team(players,'Manchester United')
players_on_manchester_united
# Out:
# ['Cristiano Ronaldo', 'De Gea']

# %% [markdown]
# ## Pandas and Numpy

# %% [markdown]
# In this section you will be doing some preprocessing and exploratory data analysis for a dataset for the videogame FIFA19 (https://www.kaggle.com/karangadiya/fifa19).  The dataset contains both data for the game as well as information about the players' real life careers.

# %% [markdown]
# **1) Read the CSV file into a pandas dataframe**
#
# The data you'll be working with is found in a file called './data/fifa.csv'.  Use your knowledge of pandas to create a new dataframe using the csv data.
#
# Check the contents of your dataframe with `df.head()`</b>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./data/fifa.csv')
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0       226500.0
# 1      7.0        11.0       15.0           14.0       11.0       127100.0
# 2      9.0         9.0       15.0           15.0       11.0       228100.0
# 3     90.0        85.0       87.0           88.0       94.0       138600.0
# 4     15.0        13.0        5.0           10.0       13.0       196400.0
#
# [5 rows x 89 columns]

# %% [markdown]
# **2) Check for duplicates**
#
# **First, check how many columns and rows are in the dataset, then check how many unique values are in the "ID" column.**

# %%
# code here to see the size of the dataframe
df.shape
# Out:
# (20000, 89)

# %%
# code here to check number of unique ids
len(df.ID.unique())
# Out:
# 18207

# %% [markdown]
# <b> 3) Drop Duplicates
#
# It looks like there are duplicates.  Get rid of them by dropping duplicate rows. After you have dropped them, see how many rows are remaining.</b>

# %%
# code here
df.drop_duplicates(subset='ID', inplace=True)

# %%
# now see how many rows there are
df_old_shape = df.shape
df_old_shape
# Out:
# (18207, 89)

# %% [markdown]
# <b> 4. Drop n/a rows for "Release Clause"
#
# Drop rows for which "Release Clause" is none or not given. This is part of a soccer player's contract dealing with being bought out by another team. After you have dropped them, see how many rows are remaining.</b>

# %%
# code here to drop n/a rows
df_na_shape = df.loc[df['Release Clause'].isna(), :].shape
df_na_shape
# Out:
# (1564, 89)

# %%
df.dropna(axis=0, subset=['Release Clause'], inplace=True)
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 19995        9995  238813        J. Lundstram   19
# 19996        9996  243165  N. Christoffersson   19
# 19997        9997  241638           B. Worman   16
# 19998        9998  246268      D. Walker-Rice   17
# 19999        9999  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 19995  https://cdn.sofifa.org/players/4/19/238813.png     England
# 19996  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 19997  https://cdn.sofifa.org/players/4/19/241638.png     England
# 19998  https://cdn.sofifa.org/players/4/19/246268.png     England
# 19999  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.org/flags/52.png       94         94
# 1      https://cdn.sofifa.org/flags/38.png       94         94
# 2      https://cdn.sofifa.org/flags/54.png       92         93
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 4       https://cdn.sofifa.org/flags/7.png       91         92
# ...                                    ...      ...        ...
# 19995  https://cdn.sofifa.org/flags/14.png       47         65
# 19996  https://cdn.sofifa.org/flags/46.png       47         63
# 19997  https://cdn.sofifa.org/flags/14.png       47         67
# 19998  https://cdn.sofifa.org/flags/14.png       47         66
# 19999  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club  ... Composure Marking StandingTackle  \
# 0             FC Barcelona  ...      96.0    33.0           28.0
# 1                 Juventus  ...      95.0    28.0           31.0
# 2      Paris Saint-Germain  ...      94.0    27.0           24.0
# 3        Manchester United  ...      68.0    15.0           21.0
# 4          Manchester City  ...      88.0    68.0           58.0
# ...                    ...  ...       ...     ...            ...
# 19995      Crewe Alexandra  ...      45.0    40.0           48.0
# 19996       Trelleborgs FF  ...      42.0    22.0           15.0
# 19997     Cambridge United  ...      41.0    32.0           13.0
# 19998      Tranmere Rovers  ...      46.0    20.0           25.0
# 19999      Tranmere Rovers  ...      43.0    40.0           43.0
#
#        SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning  \
# 0               26.0      6.0        11.0       15.0           14.0
# 1               23.0      7.0        11.0       15.0           14.0
# 2               33.0      9.0         9.0       15.0           15.0
# 3               13.0     90.0        85.0       87.0           88.0
# 4               51.0     15.0        13.0        5.0           10.0
# ...              ...      ...         ...        ...            ...
# 19995           47.0     10.0        13.0        7.0            8.0
# 19996           19.0     10.0         9.0        9.0            5.0
# 19997           11.0      6.0         5.0       10.0            6.0
# 19998           27.0     14.0         6.0       14.0            8.0
# 19999           50.0     10.0        15.0        9.0           12.0
#
#       GKReflexes Release Clause
# 0            8.0       226500.0
# 1           11.0       127100.0
# 2           11.0       228100.0
# 3           94.0       138600.0
# 4           13.0       196400.0
# ...          ...            ...
# 19995        9.0       143000.0
# 19996       12.0       113000.0
# 19997       13.0       165000.0
# 19998        9.0       143000.0
# 19999        9.0       165000.0
#
# [16643 rows x 89 columns]

# %%
# now check how many rows are left 
df_new_shape = df.shape
df_new_shape
# Out:
# (16643, 89)

# %%
df_old_shape[0] - df_new_shape[0] == df_na_shape[0]
# Out:
# True

# %% [markdown]
# <b> 5) Convert players' heights to inches. Replace the original height column.
# First create a function, then use it on your dataframe. Create a function that convert a string into a integer and then apply that function to all of the height column.</b>

# %%
# code here to write a helper function
def convert_height(height):
    '''
    inputs: height (string)
    ----
    returns: height in inches (int)
    '''
    h_split = height.split("'")
    h_feet = int(h_split[0])
    h_inches = int(h_split[1])
    return 12*h_feet + h_inches

# %%
# test here
convert_height("5'7")
# Out:
# 67

# %%
# code here to use the function on the height column
df['inches'] = df.Height.map(convert_height)
df.loc[:, ['Name', 'Height', 'inches']]
# Out:
#                      Name Height  inches
# 0                L. Messi    5'7      67
# 1       Cristiano Ronaldo    6'2      74
# 2               Neymar Jr    5'9      69
# 3                  De Gea    6'4      76
# 4            K. De Bruyne   5'11      71
# ...                   ...    ...     ...
# 19995        J. Lundstram    5'9      69
# 19996  N. Christoffersson    6'3      75
# 19997           B. Worman    5'8      68
# 19998      D. Walker-Rice   5'10      70
# 19999           G. Nugent   5'10      70
#
# [16643 rows x 3 columns]

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# <b> 1) Make a histogram of players age
#
# _Add a title and x axis label._ Use whichever plotting library you are most comfortable with. </b>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
# histogram
dist_ax = sns.distplot(a=df.Age, bins=30)
dist_ax.set_ylabel('Proportion of Players')
dist_ax.set_title('Histogram of Player Age')
# Out:
# Text(0.5, 1.0, 'Histogram of Player Age')

# %%
# alternative
count_ax = sns.countplot(x = 'Age', data = df)
count_ax.set_ylabel('Number of Players')
count_ax.set_title('Number of Players at a Given Age')
# Out:
# Text(0.5, 1.0, 'Number of Players at a Given Age')

# %% [markdown]
# <b> 2) Make a bar chart for the 10 countries with the most players (by nationality)</b>
#
# Make sure to include x labels on your chart!

# %%
# code here to get the top 10 countries with the most players
nationality_stats = df.groupby(by=['Nationality']).describe()

# %%
nationality_stats
# Out:
#             Unnamed: 0                                                     \
#                  count         mean          std     min      25%     50%
# Nationality
# Afghanistan        4.0  6128.500000  1275.416403  4684.0  5248.75  6251.5
# Albania           37.0  5883.567568  2519.811220   338.0  4160.00  6232.0
# Algeria           56.0  4498.928571  2603.138643    84.0  2482.00  4325.0
# Andorra            1.0  5444.000000          NaN  5444.0  5444.00  5444.0
# Angola            13.0  5249.615385  2402.693577   773.0  3902.00  5793.0
# ...                ...          ...          ...     ...      ...     ...
# Uzbekistan         2.0  4351.500000  3732.816698  1712.0  3031.75  4351.5
# Venezuela         52.0  5476.576923  2508.469077   345.0  3358.00  5100.5
# Wales            116.0  5924.629310  2640.328990    36.0  3557.75  5985.0
# Zambia             9.0  6241.444444  2960.444228  1857.0  3417.00  7288.0
# Zimbabwe          13.0  3582.615385  1850.085248   764.0  2154.00  3477.0
#
#                                  ID                 ... Release Clause  \
#                  75%     max  count           mean  ...            75%
# Nationality                                         ...
# Afghanistan  7131.25  7327.0    4.0  234743.500000  ...       731750.0
# Albania      7934.00  9798.0   37.0  221150.432432  ...       189000.0
# Algeria      6597.50  9993.0   56.0  205930.214286  ...        75675.0
# Andorra      5444.00  5444.0    1.0  192937.000000  ...       384000.0
# Angola       6854.00  8493.0   13.0  201726.153846  ...       463000.0
# ...              ...     ...    ...            ...  ...            ...
# Uzbekistan   5671.25  6991.0    2.0  189585.000000  ...       190800.0
# Venezuela    7674.75  9349.0   52.0  224791.250000  ...        20775.0
# Wales        8060.75  9981.0  116.0  199822.853448  ...       457500.0
# Zambia       8703.00  9541.0    9.0  236750.555556  ...         6600.0
# Zimbabwe     4360.00  7509.0   13.0  211857.769231  ...        15400.0
#
#                       inches                                                 \
#                   max  count       mean       std   min    25%   50%    75%
# Nationality
# Afghanistan  878000.0    4.0  68.750000  0.957427  68.0  68.00  68.5  69.25
# Albania      797000.0   37.0  71.432432  2.511535  67.0  69.00  72.0  73.00
# Algeria      979000.0   56.0  71.339286  2.429192  66.0  69.75  71.0  73.00
# Andorra      384000.0    1.0  72.000000       NaN  72.0  72.00  72.0  72.00
# Angola       956000.0   13.0  70.769231  2.241794  67.0  69.00  71.0  73.00
# ...               ...    ...        ...       ...   ...    ...   ...    ...
# Uzbekistan   250000.0    2.0  71.500000  0.707107  71.0  71.25  71.5  71.75
# Venezuela    990000.0   52.0  70.076923  2.882307  63.0  67.75  70.0  72.00
# Wales        998000.0  116.0  71.586207  2.359325  66.0  70.00  71.0  73.00
# Zambia       610000.0    9.0  70.888889  2.204793  67.0  70.00  70.0  72.00
# Zimbabwe     958000.0   13.0  70.230769  2.948272  66.0  68.00  70.0  73.00
#
#
#               max
# Nationality
# Afghanistan  70.0
# Albania      77.0
# Algeria      77.0
# Andorra      72.0
# Angola       74.0
# ...           ...
# Uzbekistan   72.0
# Venezuela    77.0
# Wales        78.0
# Zambia       75.0
# Zimbabwe     74.0
#
# [161 rows x 368 columns]

# %%
top_countries = nationality_stats['Unnamed: 0']['count'].nlargest(10)
top_countries = top_countries.to_frame(name='count').reset_index()

# %%
top_countries
# Out:
#    Nationality   count
# 0      England  1475.0
# 1      Germany  1151.0
# 2        Spain   974.0
# 3       France   853.0
# 4    Argentina   833.0
# 5       Brazil   788.0
# 6        Italy   579.0
# 7     Colombia   570.0
# 8        Japan   455.0
# 9  Netherlands   426.0

# %%
# code here to plot a bar chart
plt.subplots(figsize=(10,6))
bar_ax = sns.barplot(x='Nationality', y='count', data=top_countries)
bar_ax.set_ylabel('Number of Players')
bar_ax.set_title('Top 10 Countries by Number of Players')
plt.show()

# %% [markdown]
# <b> 3) Make a scatter plot for the player stats StandingTackle and SlidingTackle
#
# What can we say about these two features? </b>

# %%
# code here to plot a scatterplot
scatter_ax = sns.scatterplot(x='StandingTackle', y='SlidingTackle', data=df)
scatter_ax.set_title('Correlation of Standing Tackles to Sliding Tackles')
# Out:
# Text(0.5, 1.0, 'Correlation of Standing Tackles to Sliding Tackles')

# %% [markdown]
# We can see using the above plot that the correlation between standing tackles and sliding tackles is relatively high, leading us to believe that in general players who are good at standing tackles are also good at sliding tackles (more broadly, players have defensive specializations). That being said, there are a lot of data points here, and we might want to further group in order to get better senses of correlation.

# %% [markdown]
# ### Exploring Statistical Data

# %% [markdown]
# We'll continue using the same FIFA 2019 dataset.  This section will assess your ability to use numpy and work with summary statistics.

# %% [markdown]
# <b>1) Convert the Release Clause Price from Euros to Dollars
#
# Create a new column that has the 'release_clause' in dollars.
#
# 1.2 Dollars = 1 Euro.</b>

# %%
# code here to convert the column of euros to dollarss
df['release_clause_dollars'] = df['Release Clause'].apply(lambda c: 1.2*c)
df['release_clause_dollars']
# Out:
# 0        271800.0
# 1        152520.0
# 2        273720.0
# 3        166320.0
# 4        235680.0
#            ...
# 19995    171600.0
# 19996    135600.0
# 19997    198000.0
# 19998    171600.0
# 19999    198000.0
# Name: release_clause_dollars, Length: 16643, dtype: float64

# %% [markdown]
# <b>2) Get summary statistics for all numeric columns
#
# (Please don't do each column individually!)</b>

# %%
# code here
df.select_dtypes(include=np.number).describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  16643.000000   16643.000000  16643.000000  16643.000000  16643.000000
# mean    5422.904945  213845.010094     25.226221     66.162771     71.140900
# std     2721.036613   30546.285826      4.716588      7.008236      6.151409
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     3175.500000  199569.500000     21.000000     62.000000     67.000000
# 50%     5488.000000  221493.000000     25.000000     66.000000     71.000000
# 75%     7770.000000  236802.000000     29.000000     71.000000     75.000000
# max     9999.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  16643.000000              16643.000000  16643.000000  16643.000000
# mean    1595.383404                  1.114823      2.942919      2.349516
# std      275.723076                  0.398559      0.659933      0.755855
# min      731.000000                  1.000000      1.000000      1.000000
# 25%     1452.000000                  1.000000      3.000000      2.000000
# 50%     1633.000000                  1.000000      3.000000      2.000000
# 75%     1787.000000                  1.000000      3.000000      3.000000
# max     2346.000000                  5.000000      5.000000      5.000000
#
#        Jersey Number  ...  StandingTackle  SlidingTackle      GKDiving  \
# count   16643.000000  ...    16643.000000   16643.000000  16643.000000
# mean       19.657213  ...       47.776302      45.751607     16.747521
# std        16.054811  ...       21.681809      21.295201     17.832273
# min         1.000000  ...        2.000000       3.000000      1.000000
# 25%         8.000000  ...       27.000000      24.000000      8.000000
# 50%        17.000000  ...       55.000000      52.000000     11.000000
# 75%        26.000000  ...       66.000000      64.000000     14.000000
# max        99.000000  ...       93.000000      91.000000     90.000000
#
#          GKHandling     GKKicking  GKPositioning    GKReflexes  \
# count  16643.000000  16643.000000   16643.000000  16643.000000
# mean      16.515712     16.355765      16.503936     16.837409
# std       17.033907     16.615668      17.151713     18.090985
# min        1.000000      1.000000       1.000000      1.000000
# 25%        8.000000      8.000000       8.000000      8.000000
# 50%       11.000000     11.000000      11.000000     11.000000
# 75%       14.000000     14.000000      14.000000     14.000000
# max       92.000000     91.000000      90.000000     94.000000
#
#        Release Clause        inches  release_clause_dollars
# count    16643.000000  16643.000000            1.664300e+04
# mean    228201.273629     71.357327            2.738415e+05
# std     299251.865865      2.642547            3.591022e+05
# min       1000.000000     61.000000            1.200000e+03
# 25%       2500.000000     69.000000            3.000000e+03
# 50%      19800.000000     71.000000            2.376000e+04
# 75%     431000.000000     73.000000            5.172000e+05
# max     999000.000000     81.000000            1.198800e+06
#
# [8 rows x 47 columns]

# %% [markdown]
# <b>3) What is the mean age and the median age for the players in this dataset?  How are the mean and median related to each other?</b>

# %%
df.Age.mean()
# Out:
# 25.226221234152497

# %%
df.Age.median()
# Out:
# 25.0

# %% [markdown]
# The mean and median are related to each other in the sense that they both describe a central measure of the data. In particular, they can both be considered a form of 'average', and their usefulness changes depending on the data in question. In a dataset with many outliers, the median may be a more representative measure of the central tendency of the data, as the mean is affected more strongly by such outliers (as the value of the outliers plays a major role in the calculation of the mean, in comparison to the median). In the case of this FIFA data, the mean and median are relatively close to each other, indicating that there are not too many outliers in the age of the players. This is further seen when considering the distribution plots above.

# %% [markdown]
# #### 4) Who is the oldest player in Argentina and how old is he?

# %%
# code here
df.loc[df.Nationality == 'Argentina', 'Age'].max()
# Out:
# 41

# %% [markdown]
# The oldest player in Argentina is 41 years old.
