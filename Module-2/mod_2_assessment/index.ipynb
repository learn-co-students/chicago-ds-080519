# %% [markdown]
# # Module 2 Assessment
#
# Welcome to your Mod 2 Assessment. You will be tested for your understanding of concepts and ability to solve problems that have been covered in class and in the curriculum.
#
# Use any libraries you want to solve the problems in the assessment.
#
# You will have up to two hours to complete this assessment.
#
# The sections of the assessment are:
#
# - Accessing Data Through APIs
# - Object Oriented Programming
# - SQL and Relational Databases
# - HTML, CSS and Web Scraping
# - Other Database Structures (MongoDB)
#
# In this assessment you will be exploring two datasets: Pokemon and Quotes.

# %%
# import the necessary libraries
import requests
import json
import pandas as pd
import sqlite3
from bs4 import BeautifulSoup
import pymongo

# %% [markdown]
# ## Part 1: Accessing Data Through APIs
#
# In this section we'll be using PokeAPI to get data on Pokemon. Let's first define functions to get information from the API. Provided below is a URL that will get you started with the first 151 Pokemon! Run the cell below to see what we get.

# %%
url = 'https://pokeapi.co/api/v2/pokemon/?limit=151'
results = requests.get(url).json()['results']
results[0]['url']
# Out:
# 'https://pokeapi.co/api/v2/pokemon/1/'

# %% [markdown]
# [Read the documentation here](https://pokeapi.co/docs/v2.html) for information on navigating this API and use the API to obtain data to answer the following questions.
#
# ### Accessing Data
#
# 1. For any **one** Pokemon, retrieve the following information in a dictionary format with the following keys:
#     - ID
#     - Name
#     - Base experience
#     - Weight
#     - Height
#     - Types
#
# The `types` attribute is going to require some manipulation of the data. The API does not respond with the data in the desired format. You might want to write helper functions to convert the format the API responds with to a `list` of `strings`.
#
# Your output should look like this:
#
# ```
# {'id': 1,
# 'name': 'bulbasaur',
# 'base_experience': 64,
# 'weight': 69,
# 'height': 7,
# 'types': ['poison', 'grass']}
# ```

# %%
# you may define any helper functions here
r = requests.get('https://pokeapi.co/api/v2/pokemon/1/')
resp = r.json()
resp['name']
# Out:
# 'bulbasaur'

# %%
def get_pokedata(url):
    
    """
    url is a string of the URL that will get you the relevant info from the API
    for a single pokemon. 
    Example: "https://pokeapi.co/api/v2/pokemon/1/"
    
    this function should return the dictionary for ONE pokemon
    
    """
    pokemon = {}
    attrs = ['id','name','base_experience','weight','height','types']
    r = requests.get(url)
    resp = r.json()
    for item in attrs:
        pokemon[item] = resp[item]  
    return pokemon
        

get_pokedata('https://pokeapi.co/api/v2/pokemon/1')
# Out:
# {'id': 1,
#  'name': 'bulbasaur',
#  'base_experience': 64,
#  'weight': 69,
#  'height': 7,
#  'types': [{'slot': 2,
#    'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#   {'slot': 1,
#    'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]}

# %% [markdown]
# ### Processing All The Data
#
# 2. Get the same information for the first **151** Pokemon as a list of dictionaries ordered by Pokemon ID. Print the first and last elements of the list. Your output should save the list to a variable and look like this:
#
# ```
# [{'id': 1,
# 'name': 'bulbasaur',
# 'base_experience': 64,
# 'weight': 69,
# 'height': 7,
# 'types': ['poison', 'grass']},
# {'id': 2,
# 'name': 'ivysaur',
# 'base_experience': 142,
# 'weight': 130,
# 'height': 10,
# 'types': ['poison', 'grass']}, ... ]
# ```

# %%
""" 

Assign to "pokedata" the list of 151 dictionaries.
You may use your function from the previous question.

"""

# Your code here
pokedata = []
# url_list = []
for element in results:
#     url_list.append(element['url'])
    pokedata.append(get_pokedata(element['url']))    
pokedata
# Out:
# [{'id': 1,
#   'name': 'bulbasaur',
#   'base_experience': 64,
#   'weight': 69,
#   'height': 7,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 2,
#   'name': 'ivysaur',
#   'base_experience': 142,
#   'weight': 130,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 3,
#   'name': 'venusaur',
#   'base_experience': 236,
#   'weight': 1000,
#   'height': 20,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 4,
#   'name': 'charmander',
#   'base_experience': 62,
#   'weight': 85,
#   'height': 6,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 5,
#   'name': 'charmeleon',
#   'base_experience': 142,
#   'weight': 190,
#   'height': 11,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 6,
#   'name': 'charizard',
#   'base_experience': 240,
#   'weight': 905,
#   'height': 17,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 7,
#   'name': 'squirtle',
#   'base_experience': 63,
#   'weight': 90,
#   'height': 5,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 8,
#   'name': 'wartortle',
#   'base_experience': 142,
#   'weight': 225,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 9,
#   'name': 'blastoise',
#   'base_experience': 239,
#   'weight': 855,
#   'height': 16,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 10,
#   'name': 'caterpie',
#   'base_experience': 39,
#   'weight': 29,
#   'height': 3,
#   'types': [{'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 11,
#   'name': 'metapod',
#   'base_experience': 72,
#   'weight': 99,
#   'height': 7,
#   'types': [{'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 12,
#   'name': 'butterfree',
#   'base_experience': 178,
#   'weight': 320,
#   'height': 11,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 13,
#   'name': 'weedle',
#   'base_experience': 39,
#   'weight': 32,
#   'height': 3,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 14,
#   'name': 'kakuna',
#   'base_experience': 72,
#   'weight': 100,
#   'height': 6,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 15,
#   'name': 'beedrill',
#   'base_experience': 178,
#   'weight': 295,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 16,
#   'name': 'pidgey',
#   'base_experience': 50,
#   'weight': 18,
#   'height': 3,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 17,
#   'name': 'pidgeotto',
#   'base_experience': 122,
#   'weight': 300,
#   'height': 11,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 18,
#   'name': 'pidgeot',
#   'base_experience': 216,
#   'weight': 395,
#   'height': 15,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 19,
#   'name': 'rattata',
#   'base_experience': 51,
#   'weight': 35,
#   'height': 3,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 20,
#   'name': 'raticate',
#   'base_experience': 145,
#   'weight': 185,
#   'height': 7,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 21,
#   'name': 'spearow',
#   'base_experience': 52,
#   'weight': 20,
#   'height': 3,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 22,
#   'name': 'fearow',
#   'base_experience': 155,
#   'weight': 380,
#   'height': 12,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 23,
#   'name': 'ekans',
#   'base_experience': 58,
#   'weight': 69,
#   'height': 20,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 24,
#   'name': 'arbok',
#   'base_experience': 157,
#   'weight': 650,
#   'height': 35,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 25,
#   'name': 'pikachu',
#   'base_experience': 112,
#   'weight': 60,
#   'height': 4,
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 26,
#   'name': 'raichu',
#   'base_experience': 218,
#   'weight': 300,
#   'height': 8,
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 27,
#   'name': 'sandshrew',
#   'base_experience': 60,
#   'weight': 120,
#   'height': 6,
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}]},
#  {'id': 28,
#   'name': 'sandslash',
#   'base_experience': 158,
#   'weight': 295,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}]},
#  {'id': 29,
#   'name': 'nidoran-f',
#   'base_experience': 55,
#   'weight': 70,
#   'height': 4,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 30,
#   'name': 'nidorina',
#   'base_experience': 128,
#   'weight': 200,
#   'height': 8,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 31,
#   'name': 'nidoqueen',
#   'base_experience': 227,
#   'weight': 600,
#   'height': 13,
#   'types': [{'slot': 2,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}},
#    {'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 32,
#   'name': 'nidoran-m',
#   'base_experience': 55,
#   'weight': 90,
#   'height': 5,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 33,
#   'name': 'nidorino',
#   'base_experience': 128,
#   'weight': 195,
#   'height': 9,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 34,
#   'name': 'nidoking',
#   'base_experience': 227,
#   'weight': 620,
#   'height': 14,
#   'types': [{'slot': 2,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}},
#    {'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 35,
#   'name': 'clefairy',
#   'base_experience': 113,
#   'weight': 75,
#   'height': 6,
#   'types': [{'slot': 1,
#     'type': {'name': 'fairy', 'url': 'https://pokeapi.co/api/v2/type/18/'}}]},
#  {'id': 36,
#   'name': 'clefable',
#   'base_experience': 217,
#   'weight': 400,
#   'height': 13,
#   'types': [{'slot': 1,
#     'type': {'name': 'fairy', 'url': 'https://pokeapi.co/api/v2/type/18/'}}]},
#  {'id': 37,
#   'name': 'vulpix',
#   'base_experience': 60,
#   'weight': 99,
#   'height': 6,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 38,
#   'name': 'ninetales',
#   'base_experience': 177,
#   'weight': 199,
#   'height': 11,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 39,
#   'name': 'jigglypuff',
#   'base_experience': 95,
#   'weight': 55,
#   'height': 5,
#   'types': [{'slot': 2,
#     'type': {'name': 'fairy', 'url': 'https://pokeapi.co/api/v2/type/18/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 40,
#   'name': 'wigglytuff',
#   'base_experience': 196,
#   'weight': 120,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'fairy', 'url': 'https://pokeapi.co/api/v2/type/18/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 41,
#   'name': 'zubat',
#   'base_experience': 49,
#   'weight': 75,
#   'height': 8,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 42,
#   'name': 'golbat',
#   'base_experience': 159,
#   'weight': 550,
#   'height': 16,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 43,
#   'name': 'oddish',
#   'base_experience': 64,
#   'weight': 54,
#   'height': 5,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 44,
#   'name': 'gloom',
#   'base_experience': 138,
#   'weight': 86,
#   'height': 8,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 45,
#   'name': 'vileplume',
#   'base_experience': 221,
#   'weight': 186,
#   'height': 12,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 46,
#   'name': 'paras',
#   'base_experience': 57,
#   'weight': 54,
#   'height': 3,
#   'types': [{'slot': 2,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 47,
#   'name': 'parasect',
#   'base_experience': 142,
#   'weight': 295,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 48,
#   'name': 'venonat',
#   'base_experience': 61,
#   'weight': 300,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 49,
#   'name': 'venomoth',
#   'base_experience': 158,
#   'weight': 125,
#   'height': 15,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 50,
#   'name': 'diglett',
#   'base_experience': 53,
#   'weight': 8,
#   'height': 2,
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}]},
#  {'id': 51,
#   'name': 'dugtrio',
#   'base_experience': 149,
#   'weight': 333,
#   'height': 7,
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}]},
#  {'id': 52,
#   'name': 'meowth',
#   'base_experience': 58,
#   'weight': 42,
#   'height': 4,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 53,
#   'name': 'persian',
#   'base_experience': 154,
#   'weight': 320,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 54,
#   'name': 'psyduck',
#   'base_experience': 64,
#   'weight': 196,
#   'height': 8,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 55,
#   'name': 'golduck',
#   'base_experience': 175,
#   'weight': 766,
#   'height': 17,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 56,
#   'name': 'mankey',
#   'base_experience': 61,
#   'weight': 280,
#   'height': 5,
#   'types': [{'slot': 1,
#     'type': {'name': 'fighting',
#      'url': 'https://pokeapi.co/api/v2/type/2/'}}]},
#  {'id': 57,
#   'name': 'primeape',
#   'base_experience': 159,
#   'weight': 320,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'fighting',
#      'url': 'https://pokeapi.co/api/v2/type/2/'}}]},
#  {'id': 58,
#   'name': 'growlithe',
#   'base_experience': 70,
#   'weight': 190,
#   'height': 7,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 59,
#   'name': 'arcanine',
#   'base_experience': 194,
#   'weight': 1550,
#   'height': 19,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 60,
#   'name': 'poliwag',
#   'base_experience': 60,
#   'weight': 124,
#   'height': 6,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 61,
#   'name': 'poliwhirl',
#   'base_experience': 135,
#   'weight': 200,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 62,
#   'name': 'poliwrath',
#   'base_experience': 230,
#   'weight': 540,
#   'height': 13,
#   'types': [{'slot': 2,
#     'type': {'name': 'fighting', 'url': 'https://pokeapi.co/api/v2/type/2/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 63,
#   'name': 'abra',
#   'base_experience': 62,
#   'weight': 195,
#   'height': 9,
#   'types': [{'slot': 1,
#     'type': {'name': 'psychic',
#      'url': 'https://pokeapi.co/api/v2/type/14/'}}]},
#  {'id': 64,
#   'name': 'kadabra',
#   'base_experience': 140,
#   'weight': 565,
#   'height': 13,
#   'types': [{'slot': 1,
#     'type': {'name': 'psychic',
#      'url': 'https://pokeapi.co/api/v2/type/14/'}}]},
#  {'id': 65,
#   'name': 'alakazam',
#   'base_experience': 225,
#   'weight': 480,
#   'height': 15,
#   'types': [{'slot': 1,
#     'type': {'name': 'psychic',
#      'url': 'https://pokeapi.co/api/v2/type/14/'}}]},
#  {'id': 66,
#   'name': 'machop',
#   'base_experience': 61,
#   'weight': 195,
#   'height': 8,
#   'types': [{'slot': 1,
#     'type': {'name': 'fighting',
#      'url': 'https://pokeapi.co/api/v2/type/2/'}}]},
#  {'id': 67,
#   'name': 'machoke',
#   'base_experience': 142,
#   'weight': 705,
#   'height': 15,
#   'types': [{'slot': 1,
#     'type': {'name': 'fighting',
#      'url': 'https://pokeapi.co/api/v2/type/2/'}}]},
#  {'id': 68,
#   'name': 'machamp',
#   'base_experience': 227,
#   'weight': 1300,
#   'height': 16,
#   'types': [{'slot': 1,
#     'type': {'name': 'fighting',
#      'url': 'https://pokeapi.co/api/v2/type/2/'}}]},
#  {'id': 69,
#   'name': 'bellsprout',
#   'base_experience': 60,
#   'weight': 40,
#   'height': 7,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 70,
#   'name': 'weepinbell',
#   'base_experience': 137,
#   'weight': 64,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 71,
#   'name': 'victreebel',
#   'base_experience': 221,
#   'weight': 155,
#   'height': 17,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 72,
#   'name': 'tentacool',
#   'base_experience': 67,
#   'weight': 455,
#   'height': 9,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 73,
#   'name': 'tentacruel',
#   'base_experience': 180,
#   'weight': 550,
#   'height': 16,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 74,
#   'name': 'geodude',
#   'base_experience': 60,
#   'weight': 200,
#   'height': 4,
#   'types': [{'slot': 2,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 75,
#   'name': 'graveler',
#   'base_experience': 137,
#   'weight': 1050,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 76,
#   'name': 'golem',
#   'base_experience': 223,
#   'weight': 3000,
#   'height': 14,
#   'types': [{'slot': 2,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 77,
#   'name': 'ponyta',
#   'base_experience': 82,
#   'weight': 300,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 78,
#   'name': 'rapidash',
#   'base_experience': 175,
#   'weight': 950,
#   'height': 17,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 79,
#   'name': 'slowpoke',
#   'base_experience': 63,
#   'weight': 360,
#   'height': 12,
#   'types': [{'slot': 2,
#     'type': {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 80,
#   'name': 'slowbro',
#   'base_experience': 172,
#   'weight': 785,
#   'height': 16,
#   'types': [{'slot': 2,
#     'type': {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 81,
#   'name': 'magnemite',
#   'base_experience': 65,
#   'weight': 60,
#   'height': 3,
#   'types': [{'slot': 2,
#     'type': {'name': 'steel', 'url': 'https://pokeapi.co/api/v2/type/9/'}},
#    {'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 82,
#   'name': 'magneton',
#   'base_experience': 163,
#   'weight': 600,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'steel', 'url': 'https://pokeapi.co/api/v2/type/9/'}},
#    {'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 83,
#   'name': 'farfetchd',
#   'base_experience': 132,
#   'weight': 150,
#   'height': 8,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 84,
#   'name': 'doduo',
#   'base_experience': 62,
#   'weight': 392,
#   'height': 14,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 85,
#   'name': 'dodrio',
#   'base_experience': 165,
#   'weight': 852,
#   'height': 18,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 86,
#   'name': 'seel',
#   'base_experience': 65,
#   'weight': 900,
#   'height': 11,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 87,
#   'name': 'dewgong',
#   'base_experience': 166,
#   'weight': 1200,
#   'height': 17,
#   'types': [{'slot': 2,
#     'type': {'name': 'ice', 'url': 'https://pokeapi.co/api/v2/type/15/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 88,
#   'name': 'grimer',
#   'base_experience': 65,
#   'weight': 300,
#   'height': 9,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 89,
#   'name': 'muk',
#   'base_experience': 175,
#   'weight': 300,
#   'height': 12,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 90,
#   'name': 'shellder',
#   'base_experience': 61,
#   'weight': 40,
#   'height': 3,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 91,
#   'name': 'cloyster',
#   'base_experience': 184,
#   'weight': 1325,
#   'height': 15,
#   'types': [{'slot': 2,
#     'type': {'name': 'ice', 'url': 'https://pokeapi.co/api/v2/type/15/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 92,
#   'name': 'gastly',
#   'base_experience': 62,
#   'weight': 1,
#   'height': 13,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'ghost', 'url': 'https://pokeapi.co/api/v2/type/8/'}}]},
#  {'id': 93,
#   'name': 'haunter',
#   'base_experience': 142,
#   'weight': 1,
#   'height': 16,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'ghost', 'url': 'https://pokeapi.co/api/v2/type/8/'}}]},
#  {'id': 94,
#   'name': 'gengar',
#   'base_experience': 225,
#   'weight': 405,
#   'height': 15,
#   'types': [{'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}},
#    {'slot': 1,
#     'type': {'name': 'ghost', 'url': 'https://pokeapi.co/api/v2/type/8/'}}]},
#  {'id': 95,
#   'name': 'onix',
#   'base_experience': 77,
#   'weight': 2100,
#   'height': 88,
#   'types': [{'slot': 2,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 96,
#   'name': 'drowzee',
#   'base_experience': 66,
#   'weight': 324,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'psychic',
#      'url': 'https://pokeapi.co/api/v2/type/14/'}}]},
#  {'id': 97,
#   'name': 'hypno',
#   'base_experience': 169,
#   'weight': 756,
#   'height': 16,
#   'types': [{'slot': 1,
#     'type': {'name': 'psychic',
#      'url': 'https://pokeapi.co/api/v2/type/14/'}}]},
#  {'id': 98,
#   'name': 'krabby',
#   'base_experience': 65,
#   'weight': 65,
#   'height': 4,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 99,
#   'name': 'kingler',
#   'base_experience': 166,
#   'weight': 600,
#   'height': 13,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 100,
#   'name': 'voltorb',
#   'base_experience': 66,
#   'weight': 104,
#   'height': 5,
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 101,
#   'name': 'electrode',
#   'base_experience': 172,
#   'weight': 666,
#   'height': 12,
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 102,
#   'name': 'exeggcute',
#   'base_experience': 65,
#   'weight': 25,
#   'height': 4,
#   'types': [{'slot': 2,
#     'type': {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 103,
#   'name': 'exeggutor',
#   'base_experience': 186,
#   'weight': 1200,
#   'height': 20,
#   'types': [{'slot': 2,
#     'type': {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'}},
#    {'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 104,
#   'name': 'cubone',
#   'base_experience': 64,
#   'weight': 65,
#   'height': 4,
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}]},
#  {'id': 105,
#   'name': 'marowak',
#   'base_experience': 149,
#   'weight': 450,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}]},
#  {'id': 106,
#   'name': 'hitmonlee',
#   'base_experience': 159,
#   'weight': 498,
#   'height': 15,
#   'types': [{'slot': 1,
#     'type': {'name': 'fighting',
#      'url': 'https://pokeapi.co/api/v2/type/2/'}}]},
#  {'id': 107,
#   'name': 'hitmonchan',
#   'base_experience': 159,
#   'weight': 502,
#   'height': 14,
#   'types': [{'slot': 1,
#     'type': {'name': 'fighting',
#      'url': 'https://pokeapi.co/api/v2/type/2/'}}]},
#  {'id': 108,
#   'name': 'lickitung',
#   'base_experience': 77,
#   'weight': 655,
#   'height': 12,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 109,
#   'name': 'koffing',
#   'base_experience': 68,
#   'weight': 10,
#   'height': 6,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 110,
#   'name': 'weezing',
#   'base_experience': 172,
#   'weight': 95,
#   'height': 12,
#   'types': [{'slot': 1,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]},
#  {'id': 111,
#   'name': 'rhyhorn',
#   'base_experience': 69,
#   'weight': 1150,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}},
#    {'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}]},
#  {'id': 112,
#   'name': 'rhydon',
#   'base_experience': 170,
#   'weight': 1200,
#   'height': 19,
#   'types': [{'slot': 2,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}},
#    {'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}]},
#  {'id': 113,
#   'name': 'chansey',
#   'base_experience': 395,
#   'weight': 346,
#   'height': 11,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 114,
#   'name': 'tangela',
#   'base_experience': 87,
#   'weight': 350,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]},
#  {'id': 115,
#   'name': 'kangaskhan',
#   'base_experience': 172,
#   'weight': 800,
#   'height': 22,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 116,
#   'name': 'horsea',
#   'base_experience': 59,
#   'weight': 80,
#   'height': 4,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 117,
#   'name': 'seadra',
#   'base_experience': 154,
#   'weight': 250,
#   'height': 12,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 118,
#   'name': 'goldeen',
#   'base_experience': 64,
#   'weight': 150,
#   'height': 6,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 119,
#   'name': 'seaking',
#   'base_experience': 158,
#   'weight': 390,
#   'height': 13,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 120,
#   'name': 'staryu',
#   'base_experience': 68,
#   'weight': 345,
#   'height': 8,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 121,
#   'name': 'starmie',
#   'base_experience': 182,
#   'weight': 800,
#   'height': 11,
#   'types': [{'slot': 2,
#     'type': {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 122,
#   'name': 'mr-mime',
#   'base_experience': 161,
#   'weight': 545,
#   'height': 13,
#   'types': [{'slot': 2,
#     'type': {'name': 'fairy', 'url': 'https://pokeapi.co/api/v2/type/18/'}},
#    {'slot': 1,
#     'type': {'name': 'psychic',
#      'url': 'https://pokeapi.co/api/v2/type/14/'}}]},
#  {'id': 123,
#   'name': 'scyther',
#   'base_experience': 100,
#   'weight': 560,
#   'height': 15,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 124,
#   'name': 'jynx',
#   'base_experience': 159,
#   'weight': 406,
#   'height': 14,
#   'types': [{'slot': 2,
#     'type': {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'}},
#    {'slot': 1,
#     'type': {'name': 'ice', 'url': 'https://pokeapi.co/api/v2/type/15/'}}]},
#  {'id': 125,
#   'name': 'electabuzz',
#   'base_experience': 172,
#   'weight': 300,
#   'height': 11,
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 126,
#   'name': 'magmar',
#   'base_experience': 173,
#   'weight': 445,
#   'height': 13,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 127,
#   'name': 'pinsir',
#   'base_experience': 175,
#   'weight': 550,
#   'height': 15,
#   'types': [{'slot': 1,
#     'type': {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'}}]},
#  {'id': 128,
#   'name': 'tauros',
#   'base_experience': 172,
#   'weight': 884,
#   'height': 14,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 129,
#   'name': 'magikarp',
#   'base_experience': 40,
#   'weight': 100,
#   'height': 9,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 130,
#   'name': 'gyarados',
#   'base_experience': 189,
#   'weight': 2350,
#   'height': 65,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 131,
#   'name': 'lapras',
#   'base_experience': 187,
#   'weight': 2200,
#   'height': 25,
#   'types': [{'slot': 2,
#     'type': {'name': 'ice', 'url': 'https://pokeapi.co/api/v2/type/15/'}},
#    {'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 132,
#   'name': 'ditto',
#   'base_experience': 101,
#   'weight': 40,
#   'height': 3,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 133,
#   'name': 'eevee',
#   'base_experience': 65,
#   'weight': 65,
#   'height': 3,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 134,
#   'name': 'vaporeon',
#   'base_experience': 184,
#   'weight': 290,
#   'height': 10,
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]},
#  {'id': 135,
#   'name': 'jolteon',
#   'base_experience': 184,
#   'weight': 245,
#   'height': 8,
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 136,
#   'name': 'flareon',
#   'base_experience': 184,
#   'weight': 250,
#   'height': 9,
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 137,
#   'name': 'porygon',
#   'base_experience': 79,
#   'weight': 365,
#   'height': 8,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 138,
#   'name': 'omanyte',
#   'base_experience': 71,
#   'weight': 75,
#   'height': 4,
#   'types': [{'slot': 2,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 139,
#   'name': 'omastar',
#   'base_experience': 173,
#   'weight': 350,
#   'height': 10,
#   'types': [{'slot': 2,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 140,
#   'name': 'kabuto',
#   'base_experience': 71,
#   'weight': 115,
#   'height': 5,
#   'types': [{'slot': 2,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 141,
#   'name': 'kabutops',
#   'base_experience': 173,
#   'weight': 405,
#   'height': 13,
#   'types': [{'slot': 2,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 142,
#   'name': 'aerodactyl',
#   'base_experience': 180,
#   'weight': 590,
#   'height': 18,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}}]},
#  {'id': 143,
#   'name': 'snorlax',
#   'base_experience': 189,
#   'weight': 4600,
#   'height': 21,
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}}]},
#  {'id': 144,
#   'name': 'articuno',
#   'base_experience': 261,
#   'weight': 554,
#   'height': 17,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'ice', 'url': 'https://pokeapi.co/api/v2/type/15/'}}]},
#  {'id': 145,
#   'name': 'zapdos',
#   'base_experience': 261,
#   'weight': 526,
#   'height': 16,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}]},
#  {'id': 146,
#   'name': 'moltres',
#   'base_experience': 261,
#   'weight': 600,
#   'height': 20,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]},
#  {'id': 147,
#   'name': 'dratini',
#   'base_experience': 60,
#   'weight': 33,
#   'height': 18,
#   'types': [{'slot': 1,
#     'type': {'name': 'dragon', 'url': 'https://pokeapi.co/api/v2/type/16/'}}]},
#  {'id': 148,
#   'name': 'dragonair',
#   'base_experience': 147,
#   'weight': 165,
#   'height': 40,
#   'types': [{'slot': 1,
#     'type': {'name': 'dragon', 'url': 'https://pokeapi.co/api/v2/type/16/'}}]},
#  {'id': 149,
#   'name': 'dragonite',
#   'base_experience': 270,
#   'weight': 2100,
#   'height': 22,
#   'types': [{'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}},
#    {'slot': 1,
#     'type': {'name': 'dragon', 'url': 'https://pokeapi.co/api/v2/type/16/'}}]},
#  {'id': 150,
#   'name': 'mewtwo',
#   'base_experience': 306,
#   'weight': 1220,
#   'height': 20,
#   'types': [{'slot': 1,
#     'type': {'name': 'psychic',
#      'url': 'https://pokeapi.co/api/v2/type/14/'}}]},
#  {'id': 151,
#   'name': 'mew',
#   'base_experience': 270,
#   'weight': 40,
#   'height': 4,
#   'types': [{'slot': 1,
#     'type': {'name': 'psychic',
#      'url': 'https://pokeapi.co/api/v2/type/14/'}}]}]

# %%
# printing first and last elements

print(pokedata[0], pokedata[-1])
# Out:
# {'id': 1, 'name': 'bulbasaur', 'base_experience': 64, 'weight': 69, 'height': 7, 'types': [{'slot': 2, 'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}, {'slot': 1, 'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}]} {'id': 151, 'name': 'mew', 'base_experience': 270, 'weight': 40, 'height': 4, 'types': [{'slot': 1, 'type': {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'}}]}

# %% [markdown]
# ## Part 2: Object Oriented Programming
#
# We're going to use the data gathered in the previous section on APIs for this section on Object Oriented Programming to instantiate Pokemon objects and write instance methods.
#
# ### Creating a Class
#
# 1. Create a class called `Pokemon` with an `__init__` method to instantiate the following attributes:
#     - ID
#     - Name
#     - Base experience
#     - Weight
#     - Height
#     - Types

# %%
# if you were unable to get the data from the API in the right format,
# uncomment the code below to access a JSON file with the list of dictionaries

# with open('data/pokemon.json') as f:  
#     pokelist = json.load(f)

# %%
"""
Create your class below with the correct syntax, including an __init__ method.
"""
class Pokemon():
    def __init__(self):
        self.ID = 'ID'
        self.name = 'name'
        self.base_experience = None
        self.weight = None
        self.heigth = None
        self.types = None

# %% [markdown]
#
# ### Instantiating Objects
#
# 2. Using the data you obtained from the API, instantiate the first, fourth and seventh Pokemon. Assign them to the variables `bulbasaur`, `charmander` and `squirtle`.

# %%
# Your code here
bulbasaur = Pokemon()
bulbasaur.name = pokedata[0]['name']
bulbasaur.ID = pokedata[0]['id']

# %%
# run this cell to test and check your code
# you may need to edit the attribute variable names if you named them differently!

def print_pokeinfo(pokemon_object):
    o = pokemon_object
    print('ID: ' + str(o.ID) + '\n' +
          'Name: ' + o.name.title() + '\n' +
          'Base experience: ' + str(o.exp) + '\n' +
          'Weight: ' + str(o.weight) + '\n' +
          'Height: ' + str(o.height) + '\n' +
          'Types: ' + str(o.types) + '\n'+)
    
print_pokeinfo(bulbasaur)
print_pokeinfo(ivysaur)
print_pokeinfo(venusaur)
# Out:
#   File "<ipython-input-10-60404c2b0005>", line 11
#     'Types: ' + str(o.types) + '\n'+)
#                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Instance Methods
#
# 3. Write an instance method within the class `Pokemon` to find the BMI of a Pokemon. BMI is defined by $\frac{weight}{height^{2}}$ with weight in **kilograms** and height in **meters**. The height and weight data of Pokemon from the API is in **decimeters** and **hectograms** respectively.
#
#
#     1 decimeter = 0.1 meters
#     1 hectogram = 0.1 kilograms

# %%
# run this cell to test and check your code
# you will probably have to rerun the code to instantiate your objects

print(bulbasaur.bmi()) # 14.08
print(charmander.bmi()) # 23.61
print(squirtle.bmi()) # 36

# %% [markdown]
# ## Part 3: SQL and Relational Databases
#
# For this section, we've put the Pokemon data into SQL tables. You won't need to use your list of dictionaries or the JSON file for this section. The schema of `pokemon.db` is as follows:
#
# <img src="data/pokemondb.png" alt="db schema" style="width:500px;"/>
#
# Assign your SQL queries as strings to the variables `q1`, `q2`, etc. and run the cells at the end of this section to print your results as Pandas DataFrames.
#
# - q1: query all columns from `Pokemon` the Pokemon that have base_experience above 200
#
#
# - q2: query the id, name, type1 and type2 of Pokemon that have **water** types as either their first or second type
#
#
# - q3: query the average weight of Pokemon by their first type in descending order
#
#
# - q4: query the Pokemon name, Pokemon type2, and what **type2** has "2xdamage" to
#
#
# - q5: query the top 5 most common type1s, the minimum height, maximum height, minimum weight and maximum weight of pokemon with those type1s, and what associated type they do "0.5xdamage" to
#
#
# **Important note on syntax**: use `double quotes ""` when quoting strings **within** your query and wrap the entire query in `single quotes ''` For the column titles that begin with numbers, you need to wrap the column names in double quotes.

# %%
cnx = sqlite3.connect('data/pokemon.db')
cur = cnx.cursor()
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
df = pd.DataFrame(cur.execute("""SELECT * FROM pokemon;""").fetchall())
df.columns = [x[0] for x in cur.description]
df.head()
# Out:
#    id        name  base_experience  weight  height  type1   type2
# 0   1   bulbasaur               64      69       7  grass  poison
# 1   2     ivysaur              142     130      10  grass  poison
# 2   3    venusaur              236    1000      20  grass  poison
# 3   4  charmander               62      85       6   fire    None
# 4   5  charmeleon              142     190      11   fire    None

# %%
# q1: query all columns from Pokemon the Pokemon that have base_experience above 200
q1 = 'SELECT * FROM pokemon WHERE base_experience > 200';
pd.read_sql(q1, cnx)
# Out:
#      id        name  base_experience  weight  height     type1     type2
# 0     3    venusaur              236    1000      20     grass    poison
# 1     6   charizard              240     905      17      fire    flying
# 2     9   blastoise              239     855      16     water      None
# 3    18     pidgeot              216     395      15    normal    flying
# 4    26      raichu              218     300       8  electric      None
# 5    31   nidoqueen              227     600      13    poison    ground
# 6    34    nidoking              227     620      14    poison    ground
# 7    36    clefable              217     400      13     fairy      None
# 8    45   vileplume              221     186      12     grass    poison
# 9    62   poliwrath              230     540      13     water  fighting
# 10   65    alakazam              225     480      15   psychic      None
# 11   68     machamp              227    1300      16  fighting      None
# 12   71  victreebel              221     155      17     grass    poison
# 13   76       golem              223    3000      14      rock    ground
# 14   94      gengar              225     405      15     ghost    poison
# 15  113     chansey              395     346      11    normal      None
# 16  144    articuno              261     554      17       ice    flying
# 17  145      zapdos              261     526      16  electric    flying
# 18  146     moltres              261     600      20      fire    flying
# 19  149   dragonite              270    2100      22    dragon    flying
# 20  150      mewtwo              306    1220      20   psychic      None
# 21  151         mew              270      40       4   psychic      None

# %%
# q2: query the id, name, type1 and type2 of Pokemon that have water types as either their first or second type
q2 = "SELECT id, name, type1, type2 FROM pokemon WHERE type1 = 'water' or type2 = 'water'"
pd.read_sql(q2, cnx)
# Out:
#      id        name  type1     type2
# 0     7    squirtle  water      None
# 1     8   wartortle  water      None
# 2     9   blastoise  water      None
# 3    54     psyduck  water      None
# 4    55     golduck  water      None
# 5    60     poliwag  water      None
# 6    61   poliwhirl  water      None
# 7    62   poliwrath  water  fighting
# 8    72   tentacool  water    poison
# 9    73  tentacruel  water    poison
# 10   79    slowpoke  water   psychic
# 11   80     slowbro  water   psychic
# 12   86        seel  water      None
# 13   87     dewgong  water       ice
# 14   90    shellder  water      None
# 15   91    cloyster  water       ice
# 16   98      krabby  water      None
# 17   99     kingler  water      None
# 18  116      horsea  water      None
# 19  117      seadra  water      None
# 20  118     goldeen  water      None
# 21  119     seaking  water      None
# 22  120      staryu  water      None
# 23  121     starmie  water   psychic
# 24  129    magikarp  water      None
# 25  130    gyarados  water    flying
# 26  131      lapras  water       ice
# 27  134    vaporeon  water      None
# 28  138     omanyte   rock     water
# 29  139     omastar   rock     water
# 30  140      kabuto   rock     water
# 31  141    kabutops   rock     water

# %%
# q3: query the average weight of Pokemon by their first type in descending order
q3 = "SELECT AVG(weight) AS average_weight, type1 FROM pokemon GROUP BY type1 ORDER BY average_weight DESC"
pd.read_sql(q3, cnx)
# Out:
#     average_weight     type1
# 0       876.111111      rock
# 1       766.000000    dragon
# 2       579.678571     water
# 3       542.857143  fighting
# 4       515.625000   psychic
# 5       500.863636    normal
# 6       480.250000      fire
# 7       480.000000       ice
# 8       452.625000    ground
# 9       317.888889  electric
# 10      279.916667     grass
# 11      273.142857    poison
# 12      237.500000     fairy
# 13      229.916667       bug
# 14      135.666667     ghost

# %%
# q4: query the Pokemon name, Pokemon type2, and what type2 has "2xdamage" to
q4 = "SELECT name, type2 FROM pokemon WHERE "
pd.read_sql(q4, cnx)

# %%
# q5: query the top 5 most common type1s, the minimum height, maximum height, minimum weight and maximum weight of pokemon with those type1s, and what associated type they do "0.5xdamage" to
q5 = ''
pd.read_sql(q5, cnx)

# %% [markdown]
# ## Section 4: Web Scraping

# %% [markdown]
# ### Accessing Data Using BeautifulSoup
#
# Use BeautifulSoup to get quotes, authors, and tags from [Quotes to Read](http://quotes.toscrape.com/).
#
# Before answering these questions, go to the site and inspect the page. Make sure to look at what links there are and how the site is structured.

# %% [markdown]
# 1. Get the first author and the path for the author's page as a tuple from the [homepage](http://quotes.toscrape.com/).

# %%
# Make a get request to retrieve the page
html_page = requests.get('http://quotes.toscrape.com/') 
# Pass the page contents to beautiful soup for parsing
soup = BeautifulSoup(html_page.content, 'html.parser')
# Your code here
author1 = soup.find('small', class_='author').text
for link in soup.findAll('a'):
    if link.get('href').startswith('/author'):
        print(link.get('href'))
# Out:
# /author/Albert-Einstein
# /author/J-K-Rowling
# /author/Albert-Einstein
# /author/Jane-Austen
# /author/Marilyn-Monroe
# /author/Albert-Einstein
# /author/Andre-Gide
# /author/Thomas-A-Edison
# /author/Eleanor-Roosevelt
# /author/Steve-Martin

# %% [markdown]
# 2. Write a function to get **all** the authors and href links for the authors from the [homepage](http://quotes.toscrape.com/)

# %%
def authors(url):
    '''
    input: url
    
    return: a dictionary of of authors and their urls
            {'author_1':'url_of_author_1', 'author_2':'url_of_author_2' ...}
    '''
    html_page = requests.get(url) 
    soup = BeautifulSoup(html_page.content, 'html.parser')
    quote_authors = {}
    for link in soup.findAll('a'):
        if link.get('href').startswith('/author'):
            quote_authors[link.get('href').strip('/author')] = link.get('href')
    return quote_authors
authors('http://quotes.toscrape.com/')
# Out:
# {'Albert-Einstein': '/author/Albert-Einstein',
#  'J-K-Rowling': '/author/J-K-Rowling',
#  'Jane-Austen': '/author/Jane-Austen',
#  'Marilyn-Monroe': '/author/Marilyn-Monroe',
#  'Andre-Gide': '/author/Andre-Gide',
#  'Thomas-A-Edison': '/author/Thomas-A-Edison',
#  'Eleanor-Roosevel': '/author/Eleanor-Roosevelt',
#  'Steve-Martin': '/author/Steve-Martin'}

# %%
# run this cell to test the function
print(authors('http://quotes.toscrape.com/'))
print('\n')
print(authors('http://quotes.toscrape.com/page/3'))
# Out:
# {'Albert-Einstein': '/author/Albert-Einstein', 'J-K-Rowling': '/author/J-K-Rowling', 'Jane-Austen': '/author/Jane-Austen', 'Marilyn-Monroe': '/author/Marilyn-Monroe', 'Andre-Gide': '/author/Andre-Gide', 'Thomas-A-Edison': '/author/Thomas-A-Edison', 'Eleanor-Roosevel': '/author/Eleanor-Roosevelt', 'Steve-Martin': '/author/Steve-Martin'}
#
#
# {'Pablo-Nerud': '/author/Pablo-Neruda', 'Ralph-Waldo-Emerson': '/author/Ralph-Waldo-Emerson', 'Mother-Teres': '/author/Mother-Teresa', 'Garrison-Keill': '/author/Garrison-Keillor', 'Jim-Henson': '/author/Jim-Henson', 'Dr-Seuss': '/author/Dr-Seuss', 'Albert-Einstein': '/author/Albert-Einstein', 'J-K-Rowling': '/author/J-K-Rowling', 'Bob-Marley': '/author/Bob-Marley'}

# %% [markdown]
# ### Pagination
#
# 3. Get the first author on each of the first 5 pages of quotes. You can get to the next page with the next button at the bottom of the homepage.

# %%
# Your code here

for i in range(2,5):
    first_5 = []
    urls = "http://books.toscrape.com//page/{}/.html".format(i)
    html_page = requests.get(url) 
    soup = BeautifulSoup(html_page.content, 'html.parser')
    for url in urls:
        authors(url)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-150-08c0c5f0bb25> in <module>
#       4     first_5 = []
#       5     urls = "http://books.toscrape.com//page/{}/.html".format(i)
# ----> 6     html_page = requests.get(url)
#       7     soup = BeautifulSoup(html_page.content, 'html.parser')
#       8     for url in urls:
#
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517             hooks=hooks,
#     518         )
# --> 519         prep = self.prepare_request(req)
#     520
#     521         proxies = proxies or {}
#
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/requests/sessions.py in prepare_request(self, request)
#     460             auth=merge_setting(auth, self.auth),
#     461             cookies=merged_cookies,
# --> 462             hooks=merge_hooks(request.hooks, self.hooks),
#     463         )
#     464         return p
#
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     311
#     312         self.prepare_method(method)
# --> 313         self.prepare_url(url, params)
#     314         self.prepare_headers(headers)
#     315         self.prepare_cookies(cookies)
#
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/requests/models.py in prepare_url(self, url, params)
#     385             error = error.format(to_native_string(url, 'utf8'))
#     386
# --> 387             raise MissingSchema(error)
#     388
#     389         if not host:
#
# MissingSchema: Invalid URL 'h': No schema supplied. Perhaps you meant http://h?

# %% [markdown]
# 4. Write a function to get all of the quotes from a page.

# %%
def get_some_quotes(url):
    '''
    input: url, number of pages to scrap (just scrape the home page if no argument is passed in)
    
    return: a list of dictionaries of quotes with their attributes
            [{'quote':'quote_1_text', 'author':'url_of_author_1'}, 
            {'quote':'quote_2_text', 'author':'url_of_author_2', 'quote_tags':[list_of_quote_2_tags]}, ...]
    '''
    pass

# %%
# set the function to a variable to use later
quotes_for_mongo = get_some_quotes('http://quotes.toscrape.com/' )
quotes_for_mongo

# %% [markdown]
# ## Part 5: MongoDB

# %% [markdown]
# To do this section, open a connection to a mongo database in the terminal, using `mongod`. You will then **create**, **update**, and **read** from a mongo database.
#
# Create and connect to a mongo database.

# %%
myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
mydb = myclient['quote_database']

# %%
mycollection = mydb['quote_collection']

# %% [markdown]
# 1. Add the quotes you obtained from the `get_some_quotes` function for the [homepage](http://quotes.toscrape.com/) to the mongo database. (You can also use the JSON file `quotes.json` to insert data into the database) To verify that you've successfully inserted the data, query it to obtain the resulting _ids back from the `results` variable.

# %%
# if you were unable to get the data from webscraping in the right format,
# uncomment the code below to access a JSON file with the list of dictionaries

with open(r"data/quotes.json", "r") as r:
    data = json.load(r)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-157-397363fd190e> in <module>
#       2 # uncomment the code below to access a JSON file with the list of dictionaries
#       3
# ----> 4 with open(r"data/quotes.json", "r") as r:
#       5     data = json.load(r)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/quotes.json'

# %%
# use the results variable to confirm the data was inserted
results = None

# %% [markdown]
# 2. Query the database for all the quotes written by `'Albert Einstein'`.

# %%
q1 = None

# %% [markdown]
# 3. Update Steve Martin's quote with the tags for the quote stored in the variable `steve_martin_tags`.

# %%
steve_martin_tags = {'quote_tags': ['change', 'deep-thoughts', 'thinking', 'world']}
update_steve = None
first_quote_tags = None

# %% [markdown]
# 4. Query the database to confirm that  `'Steve Martin'` is updated with `steve_martin_tags`.

# %%
q2 = None
